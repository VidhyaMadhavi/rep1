# %% [markdown]
# ## What is Univariate Analysis?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Univariate analysis is the simplest form of analyzing data.
# ### “Uni” means “one”, so in other words your data has only one variable.
# - it’s major purpose is to describe the data;.
# - it takes data, summarizes that data and finds patterns in the data.
# - Datasets with only one variable/column are called univariate data.
